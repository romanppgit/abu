# %%
import pydevd
pydevd.settrace('127.0.0.1', port=18889, stdoutToServer=True, stderrToServer=True)
# Out:
# pydev debugger: warning: trying to add breakpoint to file that does not exist: /Users/roman/lianghua/git/abu/abupy_ui/localhost:8888/notebooks/lianghua/git/abu/abupy_ui/参数最优交叉验证.ipynb (will have no effect)
# pydev debugger: warning: trying to add breakpoint to file that does not exist: /Users/roman/lianghua/git/abu/abupy_ui/localhost:8888/notebooks/lianghua/git/abu/abupy_ui/widget_quant_tool.py (will have no effect)
# pydev debugger: warning: trying to add breakpoint to file that does not exist: /Users/roman/lianghua/git/abu/abupy_ui/localhost:8888/notebooks/lianghua/git/abu/abupy_ui/test.py (will have no effect)
# pydev debugger: warning: trying to add breakpoint to file that does not exist: /Users/roman/lianghua/git/abu/abupy_ui/localhost:8888/notebooks/lianghua/git/abu/abupy_ui/widget_verify_tool.py (will have no effect)
# pydev debugger: warning: trying to add breakpoint to file that does not exist: /Users/roman/lianghua/git/abu/abupy_ui/localhost:8888/notebooks/lianghua/git/abu/abupy_ui/widget_verify_tool.py (will have no effect)
# Expected: /Users/roman/lianghua/git/abu/pydevd-pycharm.egg/pydevd_attach_to_process/attach_x86_64.dylib to exist.

# %%
import widget_loop_back 
widget_loop_back.show_ui()
# Out:
# VBox(children=(Tab(children=(VBox(children=(BoundedIntText(value=1000000, description='初始资金:', max=999999999, …
# 提示
# 海龟21天趋势突破买入策略已添加成功！
# 提示
# n atr止盈3.0止损1.0策略已添加成功！
# 提示
# 利润保护止盈n=1.5策略已添加成功！
# 提示
# 风险控制止损n=1.5策略已添加成功！
# Box(children=(Text(value='pid=4836 begin work'), FloatProgress(value=0.0)))
# FloatProgress(value=0.0)
# 买入后卖出的交易数量:6
# 买入后尚未卖出的交易数量:0
# 胜率:33.3333%
# 平均获利期望:24.0859%
# 平均亏损期望:-5.1732%
# 盈亏比:3.0565
# 策略收益: 20.6527%
# 基准收益: 9.8068%
# 策略年化收益: 21.8779%
# 基准年化收益: 10.3886%
# 策略买入成交比例:83.3333%
# 策略资金利用率比例:19.1173%
# 策略共执行236个交易日
# 交易买卖详情单：
#             buy_date  buy_price   buy_cnt            buy_factor    symbol  \
# 2019-12-16  20191216      5.550  135100.0  AbuFactorBuyBreak:21  sz000088
# 2020-03-04  20200304      4.940  151800.0  AbuFactorBuyBreak:21  sz000088
# 2020-06-01  20200601      4.430  169300.0  AbuFactorBuyBreak:21  sz000088
# 2020-07-03  20200703      6.080   98000.0  AbuFactorBuyBreak:21  sz000088
# 2020-08-04  20200804      9.680   41700.0  AbuFactorBuyBreak:21  sz000088
# 2020-09-24  20200924      7.225   59100.0  AbuFactorBuyBreak:21  sz000088
#
#                    buy_pos buy_type_str  expect_direction  \
# 2019-12-16  AbuAtrPosition         call               1.0
# 2020-03-04  AbuAtrPosition         call               1.0
# 2020-06-01  AbuAtrPosition         call               1.0
# 2020-07-03  AbuAtrPosition         call               1.0
# 2020-08-04  AbuAtrPosition         call               1.0
# 2020-09-24  AbuAtrPosition         call               1.0
#
#                                    sell_type_extra  sell_date  sell_price  \
# 2019-12-16  AbuFactorCloseAtrNStop:close_atr_n=1.5   20191224       5.515
# 2020-03-04         AbuFactorAtrNStop:stop_loss=1.0   20200320       4.525
# 2020-06-01  AbuFactorCloseAtrNStop:close_atr_n=1.5   20200717       6.360
# 2020-07-03  AbuFactorCloseAtrNStop:close_atr_n=1.5   20200717       6.360
# 2020-08-04  AbuFactorCloseAtrNStop:close_atr_n=1.5   20200810       9.000
# 2020-09-24  AbuFactorCloseAtrNStop:close_atr_n=1.5   20201016       6.890
#
#            sell_type ml_features  key    profit  result  profit_cg  \
# 2019-12-16      loss        None   31   -4728.5      -1    -0.0063
# 2020-03-04      loss        None   81  -62997.0      -1    -0.0840
# 2020-06-01       win        None  140  326749.0       1     0.4357
# 2020-07-03       win        None  162   27440.0       1     0.0461
# 2020-08-04      loss        None  184  -28356.0      -1    -0.0702
# 2020-09-24      loss        None  215  -19798.5      -1    -0.0464
#
#             profit_cg_hunder  keep_days
# 2019-12-16           -0.6306          8
# 2020-03-04           -8.4008         16
# 2020-06-01           43.5666         46
# 2020-07-03            4.6053         14
# 2020-08-04           -7.0248          6
# 2020-09-24           -4.6367         22
